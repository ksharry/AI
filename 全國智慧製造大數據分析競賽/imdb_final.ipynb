# %% [markdown]
# # 載入資料套件

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# 匯入必要的包
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
from pandas import set_option
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error
from sklearn import metrics
datapath = "/content/gdrive/My Drive/AI_imdb/"

# %%
data = pd.read_excel(datapath+'0714trainv5_pre.xlsx')

# %%
print("data set shape: ", data.shape) # 看有幾個rows & columns
data.head() #顯示前五筆資料
# Out:
# data set shape:  (339, 233)
#    Number  Input_A1_001  Input_A1_002  ...  Input_C_057  Input_A3_013  Input_A2_017
# 0       1           0.0           0.0  ...        0.009         0.006         -0.01
# 1       2           0.0           0.0  ...        0.015         0.006         -0.02
# 2       3           0.0           0.0  ...        0.016         0.006         -0.05
# 3       4           0.0           0.0  ...        0.014         0.006         -0.02
# 4       5           0.0           0.0  ...        0.018         0.008         -0.04
#
# [5 rows x 233 columns]

# %%
#無變異
data.drop("Input_A1_010",axis=1,inplace= True)
data.drop("Input_A2_008",axis=1,inplace= True)
data.drop("Input_A2_010",axis=1,inplace= True)
data.drop("Input_A3_010",axis=1,inplace= True)
data.drop("Input_A4_010",axis=1,inplace= True)
data.drop("Input_A5_010",axis=1,inplace= True)
data.drop("Input_A6_010",axis=1,inplace= True)
data.drop("Input_C_002",axis=1,inplace= True)
data.drop("Input_C_003",axis=1,inplace= True)
data.drop("Input_C_006",axis=1,inplace= True)
data.drop("Input_C_132",axis=1,inplace= True)

# %%
data.shape
# Out:
# (339, 233)

# %%
# 分離資料集
array = data.values
X = array[:, 1:212]
y = array[:, 213:233]
test_size = 0.2 # 20%測試集
seed = 7
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

# %%
y_train
# Out:
# array([[ 0.   , -0.01 ,  0.004, ...,  0.012,  0.006, -0.02 ],
#        [-0.02 , -0.03 ,  0.005, ...,  0.007,  0.006, -0.05 ],
#        [-0.01 , -0.03 ,  0.005, ...,  0.011,  0.002, -0.02 ],
#        ...,
#        [ 0.02 , -0.01 ,  0.004, ...,  0.032,  0.006, -0.05 ],
#        [ 0.   , -0.04 ,  0.005, ...,  0.014,  0.002, -0.05 ],
#        [ 0.   , -0.05 ,  0.005, ...,  0.008,  0.006, -0.03 ]])

# %%
X_train.shape,X_test.shape
# Out:
# ((271, 211), (68, 211))

# %%
y_train.shape, y_test.shape
# Out:
# ((278, 20), (70, 20))

# %%
# ET訓練模型
scaler = StandardScaler().fit(X_train)
rescaledX = scaler.transform(X_train)
gbr = ExtraTreesRegressor(n_estimators=100)
gbr.fit(X=rescaledX, y=y_train)


# 評估演算法模型
rescaledX_test = scaler.transform(X_test)
predictions = gbr.predict(rescaledX_test)

type(rescaledX_test)

rescaledX_test

print(mean_squared_error(y_test, predictions)) # 最後求出均方誤差
# Out:
# 0.006257865457767143

# %%
print('R2 score:%.2f'%metrics.r2_score(y_test, predictions))
# Out:
# R2 score:0.33

# %%
data2 = pd.read_excel(datapath+'0728testv2.xlsx')

# %%
#無變異
data2.drop("Input_A1_010",axis=1,inplace= True)
data2.drop("Input_A2_008",axis=1,inplace= True)
data2.drop("Input_A2_010",axis=1,inplace= True)
data2.drop("Input_A3_010",axis=1,inplace= True)
data2.drop("Input_A4_010",axis=1,inplace= True)
data2.drop("Input_A5_010",axis=1,inplace= True)
data2.drop("Input_A6_010",axis=1,inplace= True)
data2.drop("Input_C_002",axis=1,inplace= True)
data2.drop("Input_C_003",axis=1,inplace= True)
data2.drop("Input_C_006",axis=1,inplace= True)
data2.drop("Input_C_132",axis=1,inplace= True)

# %%
data2.drop("Input_C_015",axis=1,inplace= True)
data2.drop("Input_C_016",axis=1,inplace= True)
data2.drop("Input_C_017",axis=1,inplace= True)
data2.drop("Input_C_018",axis=1,inplace= True)
data2.drop("Input_C_019",axis=1,inplace= True)
data2.drop("Input_C_020",axis=1,inplace= True)
data2.drop("Input_C_021",axis=1,inplace= True)
data2.drop("Input_C_022",axis=1,inplace= True)
data2.drop("Input_C_023",axis=1,inplace= True)
data2.drop("Input_C_024",axis=1,inplace= True)
data2.drop("Input_C_025",axis=1,inplace= True)
data2.drop("Input_C_026",axis=1,inplace= True)
data2.drop("Input_C_027",axis=1,inplace= True)
data2.drop("Input_C_028",axis=1,inplace= True)
data2.drop("Input_C_029",axis=1,inplace= True)
data2.drop("Input_C_030",axis=1,inplace= True)
data2.drop("Input_C_031",axis=1,inplace= True)
data2.drop("Input_C_032",axis=1,inplace= True)
data2.drop("Input_C_033",axis=1,inplace= True)
data2.drop("Input_C_034",axis=1,inplace= True)
data2.drop("Input_C_035",axis=1,inplace= True)
data2.drop("Input_C_036",axis=1,inplace= True)
data2.drop("Input_C_037",axis=1,inplace= True)
data2.drop("Input_C_038",axis=1,inplace= True)
data2.drop("Input_C_063",axis=1,inplace= True)
data2.drop("Input_C_064",axis=1,inplace= True)
data2.drop("Input_C_065",axis=1,inplace= True)
data2.drop("Input_C_066",axis=1,inplace= True)
data2.drop("Input_C_067",axis=1,inplace= True)
data2.drop("Input_C_068",axis=1,inplace= True)
data2.drop("Input_C_069",axis=1,inplace= True)
data2.drop("Input_C_070",axis=1,inplace= True)
data2.drop("Input_C_071",axis=1,inplace= True)
data2.drop("Input_C_072",axis=1,inplace= True)
data2.drop("Input_C_073",axis=1,inplace= True)
data2.drop("Input_C_074",axis=1,inplace= True)
data2.drop("Input_C_075",axis=1,inplace= True)
data2.drop("Input_C_076",axis=1,inplace= True)
data2.drop("Input_C_077",axis=1,inplace= True)
data2.drop("Input_C_078",axis=1,inplace= True)
data2.drop("Input_C_079",axis=1,inplace= True)
data2.drop("Input_C_080",axis=1,inplace= True)
data2.drop("Input_C_081",axis=1,inplace= True)
data2.drop("Input_C_082",axis=1,inplace= True)

# %%
data2 = data2.fillna(0)

# %%
# 分離資料集
array2 = data2.values
X2_train = array2[:, 1:212]
X2_test = array2[:, 213:233]

# %%
X2_train.shape,X2_test.shape
# Out:
# ((95, 211), (95, 20))

# %%
predictions2=[]

# %%
#評估演算法模型
rescaledX2_test = scaler.transform(X2_train)
predictions2 = gbr.predict(X2_train)

print(mean_squared_error(X2_test, predictions2)) # 最後求出均方誤差
# Out:
# 0.04515277648180682

# %%
print('R2 score:%.2f'%metrics.r2_score(X2_test, predictions2))
# Out:
# R2 score:0.00

# %%
 I = np.arange(start=1,stop=96)
 predictions2 = np.insert(predictions2, 0, values=I, axis=1)

# %%
data4 = pd.DataFrame(predictions2,columns=['預測筆數','Input_A6_024','Input_A3_016','Input_C_013','Input_A2_016','Input_A3_017','Input_C_050','Input_A6_001','Input_C_096','Input_A3_018','Input_A6_019','Input_A1_020','Input_A6_011','Input_A3_015','Input_C_046','Input_C_049','Input_A2_024','Input_C_058','Input_C_057','Input_A3_013','Input_A2_017'])

# %%
decimals = pd.Series([0,2,2,3,2,2,3,2,2,2,2,1,3,2,4,4,2,3,3,3,2], index=['預測筆數','Input_A6_024','Input_A3_016','Input_C_013','Input_A2_016','Input_A3_017','Input_C_050','Input_A6_001','Input_C_096','Input_A3_018','Input_A6_019','Input_A1_020','Input_A6_011','Input_A3_015','Input_C_046','Input_C_049','Input_A2_024','Input_C_058','Input_C_057','Input_A3_013','Input_A2_017'])

# %%
data4.round(decimals)
# Out:
#     預測筆數  Input_A6_024  Input_A3_016  ...  Input_C_057  Input_A3_013  Input_A2_017
# 0    1.0          0.00         -0.03  ...        0.013         0.005         -0.03
# 1    2.0          0.00         -0.03  ...        0.014         0.005         -0.03
# 2    3.0          0.01         -0.03  ...        0.013         0.005         -0.03
# 3    4.0          0.01         -0.03  ...        0.013         0.005         -0.03
# 4    5.0          0.01         -0.03  ...        0.012         0.005         -0.03
# ..   ...           ...           ...  ...          ...           ...           ...
# 90  91.0          0.01         -0.03  ...        0.012         0.005         -0.03
# 91  92.0          0.01         -0.03  ...        0.012         0.005         -0.03
# 92  93.0          0.00         -0.03  ...        0.014         0.005         -0.03
# 93  94.0          0.01         -0.03  ...        0.012         0.005         -0.03
# ...

# %%
# 提交檔案
data4.round(decimals).to_excel(datapath+'0728test_finalans.xlsx', index=False )
